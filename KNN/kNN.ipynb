# %%
# import necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

sns.set()

# %%
#Loading the data
data = pd.read_csv('/content/cardio_train.csv',delimiter=';')
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active  cardio
# 0     0       1       0
# 1     0       1       1
# 2     0       0       1
# 3     0       1       1
# 4     0       0       0

# %%
# import necessary libraries from Scikit
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from sklearn.model_selection import train_test_split, StratifiedKFold, GridSearchCV

# %% [markdown]
# Storing the cardio (target) in another variable and Dropping the cardio column from the dataframe

# %%
y=data["cardio"]
data.drop(['cardio'],axis = 1, inplace = True)
data.head()
# Out:
#    id    age  gender  height  weight  ap_hi  ap_lo  cholesterol  gluc  smoke  \
# 0   0  18393       2     168    62.0    110     80            1     1      0
# 1   1  20228       1     156    85.0    140     90            3     1      0
# 2   2  18857       1     165    64.0    130     70            3     1      0
# 3   3  17623       2     169    82.0    150    100            1     1      0
# 4   4  17474       1     156    56.0    100     60            1     1      0
#
#    alco  active
# 0     0       1
# 1     0       1
# 2     0       0
# 3     0       1
# 4     0       0

# %% [markdown]
# Splitting the dataset into train and test sets in the ratio of 70:30 respectively

# %%
X_train, X_test, Y_train,  Y_test = train_test_split(data.values, y.values, test_size =0.3, random_state=17)
print("Size of training set :" + str(len(X_train))+ " " + "Size of testing set :"+ str(len(X_test)))
# Out:
# Size of training set :49000 Size of testing set :21000

# %%
sca = StandardScaler()
X_train_scaled = sca.fit_transform(X_train)
X_test_scaled = sca.transform(X_test)

# %% [markdown]
# Training the k-Nearest Neighbour Classifier with n_neighbors(parameter) = 5

# %%
knn = KNeighborsClassifier(n_neighbors=5)
knn.fit(X_train_scaled, Y_train)
# Out:
# KNeighborsClassifier()

# %% [markdown]
# Predicting the trained Decision Tree Classifier on test set

# %%
Y_pred = knn.predict(X_test_scaled)
accuracy_score(Y_test, Y_pred)
# Out:
# 0.6202857142857143

# %% [markdown]
# Cross Validating over 5 folds to find the optimal parameters

# %%
knn_params = {"n_neighbors": range(5,100,10)}
knn_cv = GridSearchCV(knn, knn_params,cv=5)
knn_cv.fit(X_train_scaled, Y_train)
# Out:
# GridSearchCV(cv=5, estimator=KNeighborsClassifier(),
#              param_grid={'n_neighbors': range(5, 100, 10)})

# %%
knn_cv.best_params_
# Out:
# {'n_neighbors': 65}

# %%
knn_cv.best_score_
# Out:
# 0.6499591836734695
